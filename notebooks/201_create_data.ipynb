# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
timestamps = np.arange(0, 24 * 3600 * 14, 60)

# %%
60 * 60 * 24 * 14
# Out:
# 1209600

# %%
timestamps
# Out:
# array([      0,      60,     120, ..., 1209420, 1209480, 1209540],
#       shape=(20160,))

# %%
num_points = len(timestamps)
num_points
# Out:
# 20160

# %%
values1 = np.random.rand(num_points)
values1
# Out:
# array([0.46904602, 0.17935586, 0.44236455, ..., 0.26318763, 0.8150967 ,
#        0.11981529], shape=(20160,))

# %%
type(values1)
# Out:
# numpy.ndarray

# %%
dataset1 = np.array([timestamps, values1])

# %%
dataset1
# Out:
# array([[0.00000000e+00, 6.00000000e+01, 1.20000000e+02, ...,
#         1.20942000e+06, 1.20948000e+06, 1.20954000e+06],
#        [4.43858874e-01, 3.02903423e-01, 1.89728533e-03, ...,
#         3.67021627e-01, 1.93897361e-01, 8.42080871e-01]], shape=(2, 20160))

# %%
dataframe1 = pd.DataFrame(dataset1.T, columns=['timestamp', 'sensor1'])

# %%
dataframe1.head()
# Out:
#    timestamp   sensor1
# 0        0.0  0.469046
# 1       60.0  0.179356
# 2      120.0  0.442365
# 3      180.0  0.685096
# 4      240.0  0.746111

# %%
dataframe1.set_index('timestamp', inplace=True)

# %%
dataframe1.tail()
# Out:
#             sensor1
# timestamp
# 1209300.0  0.695813
# 1209360.0  0.906117
# 1209420.0  0.263188
# 1209480.0  0.815097
# 1209540.0  0.119815

# %%
dataframe1.head(100).plot(kind='line', figsize=(20, 10))
# Out:
# <Axes: xlabel='timestamp'>

# %%
dataframe1.head(100).plot(kind='bar', figsize=(20, 10))
# Out:
# <Axes: xlabel='timestamp'>

# %%
dataframe1.head(100).plot(kind='bar', figsize=(20, 10))
# Out:
# <Axes: xlabel='timestamp'>

# %%
dataframe1.head(100).plot()
# Out:
# <Axes: xlabel='timestamp'>

# %%
dataframe1.head(100).plot(kind='barh', figsize=(20, 10))
# Out:
# <Axes: ylabel='timestamp'>

# %%
dataframe1.head(100).plot(kind='hist', figsize=(20, 10))
# Out:
# <Axes: ylabel='Frequency'>

# %%
dataframe1.plot(kind='hist', figsize=(20, 10))
# Out:
# <Axes: ylabel='Frequency'>

# %%
dataframe1.plot(kind='box', figsize=(20, 10))
# Out:
# <Axes: >

# %%
len(dataframe1)
# Out:
# 20160

# %%
values2 = np.sin(timestamps)

# %%
values2
# Out:
# array([ 0.        , -0.30481062,  0.58061118, ...,  0.88013549,
#        -0.98295295,  0.9922188 ], shape=(20160,))

# %%
timestamps
# Out:
# array([      0,      60,     120, ..., 1209420, 1209480, 1209540],
#       shape=(20160,))

# %%
dataset2 = np.array([timestamps, values2])

# %%
dataframe2 = pd.DataFrame(dataset2.T, columns=['timestamp', 'sensor2'])

# %%
dataframe2.head()
# Out:
#    timestamp   sensor2
# 0        0.0  0.000000
# 1       60.0 -0.304811
# 2      120.0  0.580611
# 3      180.0 -0.801153
# 4      240.0  0.945445

# %%
dataframe2.set_index('timestamp', inplace=True)

# %%
dataframe2.head()
# Out:
#             sensor2
# timestamp
# 0.0        0.000000
# 60.0      -0.304811
# 120.0      0.580611
# 180.0     -0.801153
# 240.0      0.945445

# %%
dataframe2.head(100).plot()
# Out:
# <Axes: xlabel='timestamp'>

# %%
dataframe2.plot()
# Out:
# <Axes: xlabel='timestamp'>

# %%
dataframe2.head(100).plot(kind='line', figsize=(20, 10))
# Out:
# <Axes: xlabel='timestamp'>

# %%
dataframe2.plot(kind='box', figsize=(20, 10))
# Out:
# <Axes: >

# %%
dataframe2.plot(kind='hist', figsize=(20, 10))
# Out:
# <Axes: ylabel='Frequency'>

# %%
dataframes_dict = {'dataframe1': dataframe1, 'dataframe2': dataframe2}

# %%
dataframes_dict
# Out:
# {'dataframe1':             sensor1
#  timestamp
#  0.0        0.469046
#  60.0       0.179356
#  120.0      0.442365
#  180.0      0.685096
#  240.0      0.746111
#  ...             ...
#  1209300.0  0.695813
#  1209360.0  0.906117
#  1209420.0  0.263188
#  1209480.0  0.815097
#  1209540.0  0.119815
#
#  [20160 rows x 1 columns],
#  'dataframe2':             sensor2
#  timestamp
#  0.0        0.000000
#  60.0      -0.304811
#  120.0      0.580611
#  180.0     -0.801153
#  240.0      0.945445
#  ...             ...
#  1209300.0  0.440960
#  1209360.0 -0.693552
#  1209420.0  0.880135
#  1209480.0 -0.982953
#  1209540.0  0.992219
#
#  [20160 rows x 1 columns]}

# %%
def generate_training_dataset():
    timestamps = np.arange(0, 24 * 3600 * 14, 60)
    num_points = len(timestamps)

    sensor1_values = np.random.rand(num_points)
    dataset1 = np.array([timestamps, sensor1_values])
    dataframe1 = pd.DataFrame(dataset1.T, columns=['timestamp', 'sensor1'])
    dataframe1.set_index('timestamp', inplace=True)

    sensor2_values = np.sin(timestamps)
    dataset2 = np.array([timestamps, sensor2_values])
    dataframe2 = pd.DataFrame(dataset2.T, columns=['timestamp', 'sensor2'])
    dataframe2.set_index('timestamp', inplace=True)

    dataframes_dict = {'dataframe1': dataframe1, 'dataframe2': dataframe2}
    
    return dataframes_dict

# %%
generate_training_dataset()
# Out:
# {'dataframe1':             sensor1
#  timestamp
#  0.0        0.746457
#  60.0       0.115496
#  120.0      0.672734
#  180.0      0.835060
#  240.0      0.004750
#  ...             ...
#  1209300.0  0.051120
#  1209360.0  0.272081
#  1209420.0  0.256442
#  1209480.0  0.782162
#  1209540.0  0.895753
#
#  [20160 rows x 1 columns],
#  'dataframe2':             sensor2
#  timestamp
#  0.0        0.000000
#  60.0      -0.304811
#  120.0      0.580611
#  180.0     -0.801153
#  240.0      0.945445
#  ...             ...
#  1209300.0  0.440960
#  1209360.0 -0.693552
#  1209420.0  0.880135
#  1209480.0 -0.982953
#  1209540.0  0.992219
#
#  [20160 rows x 1 columns]}

# %%
def generate_scoring_dataset():
    timestamps = np.arange(0, 24 * 3600, 60)
    num_points = len(timestamps)

    sensor1_values = np.random.rand(num_points)
    sensor1_values[0:100] = 2 * np.random.rand(100)  # Introducing some variations for the first 100 points
    dataset1 = np.array([timestamps, sensor1_values])
    dataframe1 = pd.DataFrame(dataset1.T, columns=['timestamp', 'sensor1'])
    dataframe1.set_index('timestamp', inplace=True)

    sensor2_values = np.sin(timestamps)
    dataset2 = np.array([timestamps, sensor2_values])
    dataframe2 = pd.DataFrame(dataset2.T, columns=['timestamp', 'sensor2'])
    dataframe2.set_index('timestamp', inplace=True)

    dataframes_dict = {'dataframe1': dataframe1, 'dataframe2': dataframe2}

    return dataframes_dict

# %%
generate_scoring_dataset()
# Out:
# {'dataframe1':             sensor1
#  timestamp
#  0.0        1.160900
#  60.0       1.848458
#  120.0      1.815954
#  180.0      0.260667
#  240.0      1.039444
#  ...             ...
#  86100.0    0.167069
#  86160.0    0.474562
#  86220.0    0.577144
#  86280.0    0.664898
#  86340.0    0.102912
#
#  [1440 rows x 1 columns],
#  'dataframe2':             sensor2
#  timestamp
#  0.0        0.000000
#  60.0      -0.304811
#  120.0      0.580611
#  180.0     -0.801153
#  240.0      0.945445
#  ...             ...
#  86100.0    0.998256
#  86160.0   -0.968744
#  86220.0    0.847033
#  86280.0   -0.644706
#  86340.0    0.381019
#
#  [1440 rows x 1 columns]}

# %%
scoring_data = generate_scoring_dataset(np)

# %%
scoring_data['dataframe1'].plot()
# Out:
# <Axes: xlabel='timestamp'>
